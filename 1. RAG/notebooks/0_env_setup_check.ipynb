# %%
# !pip install -r ../requirements.txt
# !pip install langchain-openai
# !pip install --upgrade torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.1.2)
# Collecting torch
#   Downloading torch-2.11.0-cp311-cp311-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: torchvision in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.16.2)
# Collecting torchvision
#   Downloading torchvision-0.26.0-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: torchaudio in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.1.2)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from torch) (65.5.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch) (2023.12.2)
# Requirement already satisfied: numpy in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\razer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch) (2.1.3)
# Downloading torch-2.11.0-cp311-cp311-win_amd64.whl (114.5 MB)
#    ---------------------------------------- 0.0/114.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/114.5 MB 1.7 MB/s eta 0:01:06
#    ---------------------------------------- 0.5/114.5 MB 6.3 MB/s eta 0:00:19
#     --------------------------------------- 2.2/114.5 MB 17.3 MB/s eta 0:00:07
#    - -------------------------------------- 4.1/114.5 MB 24.0 MB/s eta 0:00:05
#    -- ------------------------------------- 6.0/114.5 MB 27.5 MB/s eta 0:00:04
#    -- ------------------------------------- 8.4/114.5 MB 31.6 MB/s eta 0:00:04
#    --- ------------------------------------ 10.7/114.5 MB 46.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 13.2/114.5 MB 50.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 15.3/114.5 MB 50.4 MB/s eta 0:00:02
#    ------ --------------------------------- 17.5/114.5 MB 50.4 MB/s eta 0:00:02
#    ------ --------------------------------- 19.9/114.5 MB 50.4 MB/s eta 0:00:02
#    ------- -------------------------------- 22.5/114.5 MB 50.1 MB/s eta 0:00:02
#    -------- ------------------------------- 25.0/114.5 MB 50.4 MB/s eta 0:00:02
#    --------- ------------------------------ 27.4/114.5 MB 59.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 29.9/114.5 MB 54.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 32.4/114.5 MB 54.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 34.3/114.5 MB 54.7 MB/s eta 0:00:02
#    ------------ --------------------------- 36.1/114.5 MB 50.4 MB/s eta 0:00:02
#    ------------- -------------------------- 38.2/114.5 MB 46.7 MB/s eta 0:00:02
#    -------------- ------------------------- 40.3/114.5 MB 43.5 MB/s eta 0:00:02
#    -------------- ------------------------- 42.5/114.5 MB 43.7 MB/s eta 0:00:02
#    --------------- ------------------------ 44.7/114.5 MB 43.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 46.9/114.5 MB 43.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 49.9/114.5 MB 46.7 MB/s eta 0:00:02
#    ------------------ --------------------- 52.6/114.5 MB 54.4 MB/s eta 0:00:02
#    ------------------- -------------------- 54.6/114.5 MB 50.4 MB/s eta 0:00:02
#    ------------------- -------------------- 57.2/114.5 MB 59.5 MB/s eta 0:00:01
#    -------------------- ------------------- 59.4/114.5 MB 54.4 MB/s eta 0:00:02
#    --------------------- ------------------ 61.8/114.5 MB 54.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 64.0/114.5 MB 54.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 66.4/114.5 MB 50.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 68.7/114.5 MB 50.4 MB/s eta 0:00:01
#    ------------------------ --------------- 71.1/114.5 MB 50.4 MB/s eta 0:00:01
#    ------------------------- -------------- 73.4/114.5 MB 50.4 MB/s eta 0:00:01
#    -------------------------- ------------- 76.0/114.5 MB 50.4 MB/s eta 0:00:01
#    --------------------------- ------------ 78.3/114.5 MB 54.4 MB/s eta 0:00:01
#    --------------------------- ------------ 79.3/114.5 MB 46.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 81.3/114.5 MB 43.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 83.6/114.5 MB 43.5 MB/s eta 0:00:01
#    ------------------------------ --------- 86.2/114.5 MB 43.7 MB/s eta 0:00:01
#    ------------------------------- -------- 88.9/114.5 MB 46.9 MB/s eta 0:00:01
#    -------------------------------- ------- 91.8/114.5 MB 59.5 MB/s eta 0:00:01
#    -------------------------------- ------- 94.3/114.5 MB 59.5 MB/s eta 0:00:01
#    --------------------------------- ------ 96.6/114.5 MB 59.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 99.2/114.5 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------- ---- 101.2/114.5 MB 54.4 MB/s eta 0:00:01
#    ----------------------------------- --- 103.8/114.5 MB 50.1 MB/s eta 0:00:01
#    ------------------------------------ -- 106.2/114.5 MB 54.7 MB/s eta 0:00:01
#    ------------------------------------ -- 108.6/114.5 MB 50.4 MB/s eta 0:00:01
#    ------------------------------------- - 111.1/114.5 MB 54.7 MB/s eta 0:00:01
#    --------------------------------------  113.3/114.5 MB 50.4 MB/s eta 0:00:01
#    --------------------------------------  114.5/114.5 MB 54.4 MB/s eta 0:00:01
#    --------------------------------------  114.5/114.5 MB 54.4 MB/s eta 0:00:01
#    --------------------------------------  114.5/114.5 MB 54.4 MB/s eta 0:00:01
#    --------------------------------------  114.5/114.5 MB 54.4 MB/s eta 0:00:01
#    --------------------------------------- 114.5/114.5 MB 27.3 MB/s eta 0:00:00
# Downloading torchvision-0.26.0-cp311-cp311-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -------------------- ------------------- 2.0/4.0 MB 63.4 MB/s eta 0:00:01
#    ---------------------------------------  4.0/4.0 MB 50.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 42.3 MB/s eta 0:00:00
# Downloading torchaudio-2.11.0-cp311-cp311-win_amd64.whl (328 kB)
#    ---------------------------------------- 0.0/328.7 kB ? eta -:--:--
#    --------------------------------------- 328.7/328.7 kB 19.9 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------------ --------------------------- 2.0/6.3 MB 42.3 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 52.8 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 57.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 44.6 MB/s eta 0:00:00
# Installing collected packages: torchaudio, sympy, torch, torchvision
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.1.2
#     Uninstalling torchaudio-2.1.2:
#       Successfully uninstalled torchaudio-2.1.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2
#     Uninstalling torch-2.1.2:
#       Successfully uninstalled torch-2.1.2
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.2
#     Uninstalling torchvision-0.16.2:
#       Successfully uninstalled torchvision-0.16.2
# Successfully installed sympy-1.14.0 torch-2.11.0 torchaudio-2.11.0 torchvision-0.26.0
# [notice] A new release of pip is available: 23.3.1 -> 26.0.1
# [notice] To update, run: C:\Users\RAZER\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Check Python version
import sys
print(f"Python: {sys.version}")
# Out:
# Python: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]

# %%
# Check core imports
import langchain
import chromadb
import openai

print(f"LangChain: {langchain.__version__}")
print(f"ChromaDB: {chromadb.__version__}")
print(f"OpenAI: {openai.__version__}")
# Out:
# LangChain: 1.2.14
# ChromaDB: 1.5.5
# OpenAI: 2.30.0

# %%
# Check API key is loaded (never print the key itself)
import os
from dotenv import load_dotenv
load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
print("API key loaded:", "✅" if api_key else "❌ NOT FOUND")
# Out:
# API key loaded: ✅

# %%
use_OpenAI_LLM = False
# Quick smoke test: can we hit the OpenAI API?
from langchain_openai import ChatOpenAI

if use_OpenAI_LLM = True:
    llm = ChatOpenAI(model="gpt-4o-mini")  # cheap model, just for testing
    response = llm.invoke("Say hello in one word.")
    print("LLM response:", response.content)
# Out:
# LLM response: Hello!
